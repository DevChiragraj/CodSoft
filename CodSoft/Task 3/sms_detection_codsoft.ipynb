# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("spam.csv",encoding="ISO-8859-1")
data.head()
# Out:
#      v1                                                 v2  Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...         NaN
# 1   ham                      Ok lar... Joking wif u oni...         NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...         NaN
# 3   ham  U dun say so early hor... U c already then say...         NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0         NaN          NaN          NaN
# ...

# %%
data["v1"].value_counts()
# Out:
# ham     4825
# spam     747
# Name: v1, dtype: int64

# %%
# ham = data[data["v1"] == "ham"]
# spam = data[data["v1"] == "spam"]

# %%
# ham = ham.sample(n=800)

# %%
# ham["v1"].value_counts()

# %%
Target = pd.get_dummies(data['v1'],drop_first=True)

# %%
Target
# Out:
#       spam
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
# ...    ...
# 5567     1
# 5568     0
# 5569     0
# 5570     0
# 5571     0
#
# [5572 rows x 1 columns]

# %%
data.insert(1,'target',Target)

# %%
data.head()
# Out:
#      v1  target                                                 v2  \
# 0   ham       0  Go until jurong point, crazy.. Available only ...
# 1   ham       0                      Ok lar... Joking wif u oni...
# 2  spam       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham       0  U dun say so early hor... U c already then say...
# 4   ham       0  Nah I don't think he goes to usf, he lives aro...
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0         NaN         NaN          NaN          NaN
# ...

# %%
data.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'],inplace=True)

# %%
data.head()
# Out:
#      v1  target                                                 v2
# 0   ham       0  Go until jurong point, crazy.. Available only ...
# 1   ham       0                      Ok lar... Joking wif u oni...
# 2  spam       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham       0  U dun say so early hor... U c already then say...
# 4   ham       0  Nah I don't think he goes to usf, he lives aro...

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
from wordcloud import WordCloud
wc = WordCloud()
import string

import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def modified_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    y = []
    for i in text:
        if i.isalnum():
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))


    return " ".join(y)

# %%
data['modified_text'] = data['v2'].apply(modified_text)

# %%
data.head()
# Out:
#      v1  target                                                 v2  \
# 0   ham       0  Go until jurong point, crazy.. Available only ...
# 1   ham       0                      Ok lar... Joking wif u oni...
# 2  spam       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham       0  U dun say so early hor... U c already then say...
# 4   ham       0  Nah I don't think he goes to usf, he lives aro...
#
#                                        modified_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()

# %%
X = tfidf.fit_transform(data['modified_text']).toarray()
y = data['target'].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(C=2)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=2)

# %%
model.score(X_test,y_test)
# Out:
# 0.9587443946188341

# %%
from sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB()

# %%
from sklearn.metrics import accuracy_score,precision_score

# %%
bnb.fit(X_train,y_train)
y_pred = bnb.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9695067264573991

# %%
print(precision_score(y_test,y_pred))
# Out:
# 0.9920634920634921
